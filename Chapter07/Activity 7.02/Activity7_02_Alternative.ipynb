# %% [markdown]
# ## Summarize complaints in Consumer Financial Protection Bureau dataset using fine-tuned pre-trained BERT Extractive Summarizer (bert-extractive-summarizer) and Text Rank (gensim)
# # https://www.consumerfinance.gov/data-research/consumer-complaints/

# %%
import warnings
warnings.filterwarnings('ignore')
import os
import csv
import pandas as pd
from gensim.summarization import summarize
from transformers import pipeline
model=pipeline(task='summarization')
#from summarizer import Summarizer
#model = Summarizer(hidden=-2,random_state=12345)
# Out:
# Couldn't reach server at 'https://s3.amazonaws.com/models.huggingface.co/bert/facebook/bart-large-cnn/modelcard.json' to download model card file.
# Creating an empty model card.

# %%
complaints_pathname='./data/consumercomplaints/Consumer_Complaints.csv'
df_all_complaints=pd.read_csv(complaints_pathname)
df_all_narr=df_all_complaints.dropna(subset=['Consumer complaint narrative'])
df_all_narr=df_all_narr[['Product','Sub-product','Issue','Sub-issue','Consumer complaint narrative']]

# %%
df_part_narr=df_all_narr[df_all_narr.index.isin([242830,1086741,536367,957355,975181,483530,950006,865088,681842,536367,132345,285894])]
df_part_narr
# Out:
#                                                    Product  \
# 242830                                     Debt collection
# 1086741                                    Debt collection
# 536367                                       Consumer Loan
# 957355                         Credit card or prepaid card
# 975181   Credit reporting, credit repair services, or o...
# 483530                                     Debt collection
# 950006                                     Debt collection
# 865088   Credit reporting, credit repair services, or o...
# 681842                                    Credit reporting
# 536367                                       Consumer Loan
# 132345                                            Mortgage
# 285894                                        Prepaid card
#
#                                         Sub-product  \
# 242830                                      Medical
# 1086741       Other (i.e. phone, health club, etc.)
# 536367                                 Vehicle loan
# 957355   General-purpose credit card or charge card
# 975181                             Credit reporting
# 483530                                I do not know
# 950006                                   Other debt
# 865088                             Credit reporting
# 681842                                          NaN
# 536367                                 Vehicle loan
# 132345                                 FHA mortgage
# 285894                         General purpose card
#
#                                                      Issue  \
# 242830               Cont'd attempts collect debt not owed
# 1086741              Cont'd attempts collect debt not owed
# 536367                        Shopping for a loan or lease
# 957355   Advertising and marketing, including promotion...
# 975181                Incorrect information on your report
# 483530               Cont'd attempts collect debt not owed
# 950006   Took or threatened to take negative or legal a...
# 865088                Incorrect information on your report
# 681842              Incorrect information on credit report
# 536367                        Shopping for a loan or lease
# 132345            Loan servicing, payments, escrow account
# 285894               Managing, opening, or closing account
#
#                                                  Sub-issue  \
# 242830                                    Debt is not mine
# 1086741                                   Debt is not mine
# 536367                                                 NaN
# 957355      Didn't receive advertised or promotional terms
# 975181                       Account information incorrect
# 483530                                    Debt is not mine
# 950006   Threatened or suggested your credit would be d...
# 865088                       Account information incorrect
# 681842                                       Account terms
# 536367                                                 NaN
# 132345                                                 NaN
# 285894                                                 NaN
#
#                               Consumer complaint narrative
# 242830   XXXX XX/XX/XXXX XXXX XXXX, XXXX As a 100 % rat...
# 1086741  There was an account that was opened in the am...
# 536367   I purchased a vehicle cautiously with the assi...
# 957355   I purchased an XXXX laptop at the XXXX store u...
# 975181   opened online XXXX account was approved for ch...
# 483530   This company has called me XXXX times about a ...
# 950006   XXXX claimed they will remove the late payment...
# 865088   On XX/XX/XXXX, and XX/XX/XXXX, I have been dis...
# 681842   I had tax lien on my report, and it has been t...
# 536367   I purchased a vehicle cautiously with the assi...
# 132345   I have a trial period of loan modification HAR...
# 285894   I purchased a prepaid credit card from XXXX wh...

# %%
df_part_narr['BERT Extractive Summary']=df_part_narr['Consumer complaint narrative'].apply(lambda x: model(x,min_length=0))
#df_part_narr['BERT Extractive Summary']=df_part_narr['Consumer complaint narrative'].apply(lambda x: model(x,min_length=0,ratio=0.20))
# Out:
# Your max_length is set to 142, but you input_length is only 34. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Your max_length is set to 142, but you input_length is only 55. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Your max_length is set to 142, but you input_length is only 119. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Your max_length is set to 142, but you input_length is only 117. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Your max_length is set to 142, but you input_length is only 61. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Your max_length is set to 142, but you input_length is only 65. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Your max_length is set to 142, but you input_length is only 88. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)

# %%
def try_summarize(x,ratio):
    try:
        return(summarize(x,ratio=ratio))
    except:
        return('')
df_part_narr['TextRank Summary']=df_part_narr['Consumer complaint narrative'].apply(lambda x: try_summarize(x,ratio=0.20))

# %%
df_part_narr
# Out:
#                                                    Product  \
# 242830                                     Debt collection
# 1086741                                    Debt collection
# 536367                                       Consumer Loan
# 957355                         Credit card or prepaid card
# 975181   Credit reporting, credit repair services, or o...
# 483530                                     Debt collection
# 950006                                     Debt collection
# 865088   Credit reporting, credit repair services, or o...
# 681842                                    Credit reporting
# 536367                                       Consumer Loan
# 132345                                            Mortgage
# 285894                                        Prepaid card
#
#                                         Sub-product  \
# 242830                                      Medical
# 1086741       Other (i.e. phone, health club, etc.)
# 536367                                 Vehicle loan
# 957355   General-purpose credit card or charge card
# 975181                             Credit reporting
# 483530                                I do not know
# 950006                                   Other debt
# 865088                             Credit reporting
# 681842                                          NaN
# 536367                                 Vehicle loan
# 132345                                 FHA mortgage
# 285894                         General purpose card
#
#                                                      Issue  \
# 242830               Cont'd attempts collect debt not owed
# 1086741              Cont'd attempts collect debt not owed
# 536367                        Shopping for a loan or lease
# 957355   Advertising and marketing, including promotion...
# 975181                Incorrect information on your report
# 483530               Cont'd attempts collect debt not owed
# 950006   Took or threatened to take negative or legal a...
# 865088                Incorrect information on your report
# 681842              Incorrect information on credit report
# 536367                        Shopping for a loan or lease
# 132345            Loan servicing, payments, escrow account
# 285894               Managing, opening, or closing account
#
#                                                  Sub-issue  \
# 242830                                    Debt is not mine
# 1086741                                   Debt is not mine
# 536367                                                 NaN
# 957355      Didn't receive advertised or promotional terms
# 975181                       Account information incorrect
# 483530                                    Debt is not mine
# 950006   Threatened or suggested your credit would be d...
# 865088                       Account information incorrect
# 681842                                       Account terms
# 536367                                                 NaN
# 132345                                                 NaN
# 285894                                                 NaN
#
#                               Consumer complaint narrative  \
# 242830   XXXX XX/XX/XXXX XXXX XXXX, XXXX As a 100 % rat...
# 1086741  There was an account that was opened in the am...
# 536367   I purchased a vehicle cautiously with the assi...
# 957355   I purchased an XXXX laptop at the XXXX store u...
# 975181   opened online XXXX account was approved for ch...
# 483530   This company has called me XXXX times about a ...
# 950006   XXXX claimed they will remove the late payment...
# 865088   On XX/XX/XXXX, and XX/XX/XXXX, I have been dis...
# 681842   I had tax lien on my report, and it has been t...
# 536367   I purchased a vehicle cautiously with the assi...
# 132345   I have a trial period of loan modification HAR...
# 285894   I purchased a prepaid credit card from XXXX wh...
#
#                                    BERT Extractive Summary  \
# 242830   [{'summary_text': 'As a 100 % rated XXXX veter...
# 1086741  [{'summary_text': 'There was an account that w...
# 536367   [{'summary_text': 'I purchased a vehicle cauti...
# 957355   [{'summary_text': 'I purchased an XXXX laptop ...
# 975181   [{'summary_text': ' XXXX account was approved ...
# 483530   [{'summary_text': 'This company has called me ...
# 950006   [{'summary_text': ' XXXX claimed they will rem...
# 865088   [{'summary_text': '"I have requested proof tha...
# 681842   [{'summary_text': 'I had tax lien on my report...
# 536367   [{'summary_text': 'I purchased a vehicle cauti...
# 132345   [{'summary_text': 'Mortgage company will not s...
# 285894   [{'summary_text': 'I purchased a prepaid credi...
#
#                                           TextRank Summary
# 242830   XXXX Care coordinator XXXX XXXX contacted the ...
# 1086741
# 536367   I was advised that I could return the vehicle ...
# 957355
# 975181
# 483530
# 950006
# 865088   On XX/XX/XXXX, and XX/XX/XXXX, I have been dis...
# 681842
# 536367   I was advised that I could return the vehicle ...
# 132345   They will not acknowledge my modification, and...
# 285894        Was refused and told I have to use the card.
