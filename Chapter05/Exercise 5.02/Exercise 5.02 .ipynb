# %% [markdown]
# ## Canada Open Data Inventory using LDA

# %%
import pandas as pd
pd.set_option('display.max_colwidth', 800)
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
OPEN_DATA_URL = '../data/canada-open-data/inventory.csv'

import re

HANDLE = '@\w+'
LINK = 'https?://t\.co/\w+'
SPECIAL_CHARS = '&lt;|&lt;|&amp;|#'
PARA='\n+'
def clean(text):
    text = re.sub(LINK, ' ', text)
    text = re.sub(SPECIAL_CHARS, ' ', text)
    text = re.sub(PARA, '\n', text)
    return text

catalog=pd.read_csv(OPEN_DATA_URL)
catalog = catalog.dropna(subset=['description_en'])
file='../data/canada-open-data/catalog.txt'
catalog['description_en'].sample(frac=0.25,replace=False,random_state=0).to_csv(file,encoding='utf-8')
f=open(file,'r',encoding='utf-8')
text=f.read()
f.close()
text = clean(text)

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
doc=nlp(text)
pos_list=['NOUN']
preproc_text=[]
preproc_sent=[]

for token in doc:
    if token.text!='\n':
        if not(token.is_stop) and not(token.is_punct) and token.pos_ in pos_list:
            preproc_sent.append(token.lemma_)
    else:
        preproc_text.append(preproc_sent)
        preproc_sent=[]

preproc_text.append(preproc_sent) #last sentence

print(preproc_text)
# Out:
# [[], ['crop', 'residue', 'year', 'census'], ['investment', 'transit', 'infrastructure', 'city', 'community', 'funding', 'environment', 'greenhouse', 'gas', 'emission', 'traffic', 'congestion', 'funding', 'province', 'territory', 'capita', 'basis'], ['need', 'background', 'soil', 'datum', 'assessment', 'site', 'region', 'data', 'region', 'background', 'soil', 'concentration', 'metal', 'area', 'concentration', 'soil', 'quality', 'guideline', 'jurisdiction', 'soil', 'database', 'database', 'region', 'background', 'soil', 'screening', 'site', 'datum', 'background', 'range'], ['vegetable', 'storage', 'factory'], ['report', 'account'], ['facility', 'region', 'location', 'truck', 'trip', 'end', 'storage', 'handling', 'facility', 'business', 'dg'], ['park', 'pitcher', 'plant', 'morpology', 'availability', 'nitrogen', 'pitcher', 'plant', 'development'], ['innovation', 'business', 'strategy', 'product', 'good', 'service', 'enterprise', 'market', 'enterprise', 'size', 'industry'], ['dataset', 'result', 'radionuclide', 'analysis', 'water', 'sample', 'basis', 'sample', 'quarter', 'radium-226', 'analysis'], ['government', 'operation', 'balance', 'transaction', 'source', 'requirement'], ['license', 'stub', 'program', 'collection', 'datum', 'salmon', 'license', 'department', 'activity', 'report', 'card', 'copy', 'license', 'application', 'information', 'salmon', 'license', 'application', 'database', 'information', 'license', 'number', 'address', 'telephone', 'number', 'number', 'date', 'license', 'purchase', 'activity', 'report', 'card', 'database', 'license', 'number', 'person', 'information', 'catch', 'datum', 'program', 'purpose', 'datum', 'conjunction', 'characteristic', 'datum', 'fishway', 'fence', 'datum', 'stock', 'assessment', 'purpose', 'status', 'stock', 'provision', 'advice', 'manager', 'economist', 'sociologist', 'planner', 'tourism', 'industry'], ['vehicle', 'survey', 'fuel', 'type', 'vehicle', 'type', 'fuel'], ['indicator', 'day', 'date', 'release', 'start', 'date', 'community', 'assignment'], ['table', 'series', 'table', 'portrait', 'census', 'topic', 'table', 'complexity', 'level', 'geography', 'content', 'overview', 'country', 'tabulation', 'table', 'census'], ['summary', 'report', 'list', 'company', 'good', 'user', 'datum', 'default', 'setting', 'code', 'default', 'number'], ['overview', 'area', 'number', 'variable'], ['product', 'price', 'index'], ['balance', 'sheet'], ['database', 'name', 'purpose', 'place', 'name', 'attribute', 'body', 'standard', 'policy', 'place', 'name', 'extent', 'landmass', 'water', 'body', 'extent', 'dataset', 'basis', 'name', 'feature', 'type', 'coordinate', 'feature', 'decision', 'date', 'source', 'attribute', 'output', 'file', 'format', 'product', 'text'], ['government', 'asset', 'liability', 'province', 'territory'], ['2585,a', 'series', 'health', 'data', 'set', 'opinion', 'research', 'study'], ['activity', 'level', 'change', 'age', 'group'], ['province'], ['database', 'trade', 'datum', 'classification', 'good', 'commodity', 'level', 'variable', 'trading', 'partner', 'province', 'state', 'year', 'month', 'frequency', 'data', 'report'], ['merchandise', 'trade', 'datum', 'basis', 'month', 'year', 'year', 'custom', 'datum', 'release', 'reference', 'month', 'basis', 'year', 'custom', 'datum', 'reference', 'month'], ['price', 'index', 'chemical', 'product', 'region'], ['behaviour', 'school', 'child', 'student', 'response'], ['innovation', 'service', 'industry', 'percentage', 'time', 'employee', 'university', 'graduate'], ['bloodworm', 'dibranchiata'], ['file', 'mass', 'leaf', 'area', 'perimeter', 'needle', 'calculation', 'leaf', 'mass', 'needle', 'litter', 'box', 'perd', 'site', 'ecoleap', 'site', 'forest'], ['table', 'series', 'table', 'portrait', 'census', 'topic', 'table', 'complexity', 'level', 'geography', 'content', 'overview', 'country', 'tabulation', 'table', 'census'], ['stock', 'capital', 'industry', 'asset', 'province', 'territory'], ['end', 'year', 'government', 'information', 'dataset',  ...

# %%
import tomotopy as tp
NUM_TOPICS=20
mdl = tp.LDAModel(k=NUM_TOPICS,seed=1234)

for line in preproc_text:
    mdl.add_doc(line)

for i in range(0, 110, 10):
    mdl.train(i)
    print('Iteration: {}\tLog-likelihood: {}'.format(i, mdl.ll_per_word))
# Out:
# Iteration: 0	Log-likelihood: -11.093217577268552
# Iteration: 10	Log-likelihood: -6.8822797912226115
# Iteration: 20	Log-likelihood: -6.317129241581733
# Iteration: 30	Log-likelihood: -6.157586638884254
# Iteration: 40	Log-likelihood: -6.073628903605757
# Iteration: 50	Log-likelihood: -6.0291570377492905
# Iteration: 60	Log-likelihood: -6.005991344426762
# Iteration: 70	Log-likelihood: -5.975599517879777
# Iteration: 80	Log-likelihood: -5.959173736422274
# Iteration: 90	Log-likelihood: -5.939598846671805
# Iteration: 100	Log-likelihood: -5.935156891936913

# %%
mdl.train(10)
for k in range(mdl.k):
    print('Top 10 words of topic #{}'.format(k))
    print(mdl.get_topic_words(k, top_n=7))
# Out:
# Top 10 words of topic #0
# [('polygon', 0.036050185561180115), ('dataset', 0.033475782722234726), ('information', 0.03004324994981289), ('soil', 0.029185116291046143), ('area', 0.026610717177391052), ('surface', 0.025752583518624306), ('map', 0.024036318063735962)]
# Top 10 words of topic #1
# [('province', 0.04648945853114128), ('group', 0.03703557699918747), ('age', 0.03467210754752159), ('sex', 0.03309646248817444), ('territory', 0.03073299117386341), ('student', 0.02521822601556778), ('child', 0.023642580956220627)]
# Top 10 words of topic #2
# [('business', 0.05287355184555054), ('permit', 0.049527548253536224), ('enterprise', 0.0435047410428524), ('work', 0.041497137397527695), ('year', 0.03748193010687828), ('size', 0.03681273013353348), ('innovation', 0.03480513021349907)]
# Top 10 words of topic #3
# [('datum', 0.03372278809547424), ('forest', 0.020649272948503494), ('specie', 0.016520794481039047), ('ozone', 0.013768475502729416), ('abundance', 0.013768475502729416), ('area', 0.013080395758152008), ('resolution', 0.0123923160135746)]
# Top 10 words of topic #4
# [('information', 0.07431501895189285), ('area', 0.06688418984413147), ('datum', 0.04999595135450363), ('file', 0.04121406376361847), ('unit', 0.03783641383051872), ('mapping', 0.025001350790262222), ('housing', 0.023650292307138443)]
# Top 10 words of topic #5
# [('survey', 0.04966237023472786), ('catch', 0.03862873837351799), ('sponge', 0.0364220105111599), ('sea', 0.0342152863740921), ('datum', 0.028698472306132317), ('fishing', 0.02759511023759842), ('matter', 0.026491746306419373)]
# Top 10 words of topic #6
# [('type', 0.09624676406383514), ('decision', 0.08446264266967773), ('dataset', 0.07071451097726822), ('information', 0.0530383363366127), ('review', 0.04125422239303589), ('number', 0.03929020091891289), ('jurisdiction', 0.03339814394712448)]
# Top 10 words of topic #7
# [('type', 0.05425140634179115), ('service', 0.04361492022871971), ('industry', 0.04148762300610542), ('vehicle', 0.03989214822649956), ('survey', 0.039360322058200836), ('use', 0.022873766720294952), ('expenditure', 0.022873766720294952)]
# Top 10 words of topic #8
# [('gas', 0.11306407302618027), ('dataset', 0.06784319877624512), ('value', 0.06189308688044548), ('figure', 0.047612812370061874), ('production', 0.034522563219070435), ('export', 0.0321425162255764), ('statistic', 0.029762471094727516)]
# Top 10 words of topic #9
# [('income', 0.08024384826421738), ('farm', 0.06456581503152847), ('family', 0.04335436224937439), ('tax', 0.03782093897461891), ('type', 0.033209752291440964), ('area', 0.028598571196198463), ('province', 0.027676332741975784)]
# Top 10 words of topic #10
# [('price', 0.06705746799707413), ('index', 0.06506586074829102), ('product', 0.061082642525434494), ('service', 0.039174944162368774), ('expenditure', 0.03585559502243996), ('payment', 0.026561420410871506), ('trade', 0.022578204050660133)]
# Top 10 words of topic #11
# [('table', 0.24849626421928406), ('census', 0.1265643984079361), ('level', 0.06526772677898407), ('series', 0.06306280940771103), ('topic', 0.062401335686445236), ('geography', 0.062401335686445236), ('country', 0.06218084320425987)]
# Top 10 words of topic #12
# [('datum', 0.041923701763153076), ('water', 0.03881862387061119), ('quality', 0.02277573011815548), ('soil', 0.019153142347931862), ('monitoring', 0.01863562874495983), ('dataset', 0.01863562874495983), ('crop', 0.01811811700463295)]
# Top 10 words of topic #13
# [('air', 0.05096367374062538), ('sample', 0.036128025501966476), ('pollutant', 0.028387688100337982), ('datum', 0.024517519399523735), ('water', 0.022582434117794037), ('emission', 0.021937405690550804), ('food', 0.020647350698709488)]
# Top 10 words of topic #14
# [('group', 0.07404157519340515), ('sex', 0.07219062745571136), ('province', 0.07033967971801758), ('age', 0.05812343209981918), ('territory', 0.05146002396941185), ('population', 0.04960907623171806), ('household', 0.04553699493408203)]
# Top 10 words of topic #15
# [('number', 0.05818070471286774), ('report', 0.044884152710437775), ('day', 0.03740484640002251), ('fish', 0.030756574124097824), ('date', 0.029094504192471504), ('period', 0.02826347015798092), ('health', 0.023277267813682556)]
# Top 10 words of topic #16
# [('type', 0.040563225746154785), ('balance', 0.03396144509315491), ('road', 0.03396144509315491), ('information', 0.033018335700035095), ('name', 0.031132111325860023), ('datum', 0.030189000070095062), ('asset', 0.030189000070095062)]
# Top 10 words of topic #17
# [('datum', 0.0603327676653862), ('information', 0.057247743010520935), ('year', 0.03462424501776695), ('dataset', 0.03291034325957298), ('project', 0.01782800629734993), ('website', 0.014057422056794167), ('activity', 0.012000739574432373)]
# Top 10 words of topic #18
# [('file', 0.09657112509012222), ('datum', 0.07195736467838287), ('dataset', 0.06817063689231873), ('structure', 0.05113033950328827), ('scheme', 0.043556876480579376), ('tool', 0.037876781076192856), ('emission', 0.02840995229780674)]
# Top 10 words of topic #19
# [('datum', 0.04801705852150917), ('purpose', 0.02961205504834652), ('research', 0.018008897081017494), ('stock', 0.017208680510520935), ('survey', 0.014407917857170105), ('area', 0.01400780864059925), ('assessment', 0.01400780864059925)]

# %%
bag_of_words=[word for sent in preproc_text for word in sent]
doc_inst = mdl.make_doc(bag_of_words)
mdl.infer(doc_inst)[0]
np.argsort(np.array(mdl.infer(doc_inst)[0]))[::-1]
# Out:
# array([11, 17, 14, 19, 12,  7,  4, 13, 10,  2,  3, 15,  1, 18, 16,  9,  0,
#         6,  8,  5], dtype=int64)

# %%
print(mdl.get_topic_words(11, top_n=7))
# Out:
# [('table', 0.24849626421928406), ('census', 0.1265643984079361), ('level', 0.06526772677898407), ('series', 0.06306280940771103), ('topic', 0.062401335686445236), ('geography', 0.062401335686445236), ('country', 0.06218084320425987)]

# %%
print(mdl.get_topic_words(17, top_n=7))
# Out:
# [('datum', 0.0603327676653862), ('information', 0.057247743010520935), ('year', 0.03462424501776695), ('dataset', 0.03291034325957298), ('project', 0.01782800629734993), ('website', 0.014057422056794167), ('activity', 0.012000739574432373)]

# %%
print(mdl.get_topic_words(5, top_n=7))
# Out:
# [('survey', 0.04966237023472786), ('catch', 0.03862873837351799), ('sponge', 0.0364220105111599), ('sea', 0.0342152863740921), ('datum', 0.028698472306132317), ('fishing', 0.02759511023759842), ('matter', 0.026491746306419373)]
